# %% [markdown]
# Name : Akhil Amit Senroy
# (50288588)

# %% [markdown]
# ## Problem 1 : Define two synthetic vectors of data representing sales over 12 months for 2 items. Compare the two using lines graphs. (Discussion; Run the code multiple time and see randomness of the second set of data..)

# %%
sales1<-c(12,14,16,29,30,45,19,20,16, 19, 34, 20)
sales2<-rpois(12,34)  # random numbers, Poisson distribution, mean at 34, 12 numbers

par(bg="cornsilk")

plot(sales1, col="blue", type="o", ylim=c(0,100), xlab="Month", ylab="Sales" )
title(main="Sales by Month")

lines(sales2, type="o", pch=22, lty=2, col="red")
grid(nx=NA, ny=NULL)
legend("topright", inset=.05, c("Sales1","Sales2"), fill=c("blue","red"), horiz=TRUE)
# Out:
# Plot with title “Sales by Month”

# %% [markdown]
# ## Problem 2: The sales data is available in a table in a text file. Read it in and draw a side-by-side histogram to compare the performance. (Discussion)

# %%
sales<-read.delim("salesdata.txt", header=TRUE, sep="\t")
sales  # to verify that data has been read
barplot(as.matrix(sales), main="Sales Data", ylab= "Total",beside=T, col=rainbow(7))
# Out:
#    Sales1 Sales2
# 1  34     45
# 2  23     23
# 3  12     56
# 4  29     34
# 5  34     45
# 6  34     56
# 7  12     89
# 8  80     36
# 9  80     44
# 10 56     66
# 11 55     60
# 12 45     23
# Plot with title “Sales Data”

# %% [markdown]
# ## Problem 3: Use boxplot to compare the two sales data. (Discussion: How will you interpret the graph visualization?)

# %%
fn<-boxplot(sales,col=c("orange","green"))$stats

text(1.45, fn[3,2], paste("Median =", fn[3,2]), adj=0, cex=.7)
text(0.45, fn[3,1],paste("Median =", fn[3,1]), adj=0, cex=.7)
grid(nx=NA, ny=NULL)
# Out:
# plot without title

# %% [markdown]
# ## Problem 4: Download csv data from the web and analyze using the methods above. Download the historical prices for any two or more sticks of your choice and compare. We will do it for Apple (AAPL) and Facebook (FB) for one year.
# - We will download the csv file by specifying the URL string in the file reader in R.
# - Alternatively you can download using the data import tab of the right top quadrant of R Studio.

# %%
# Historical prices at yahoo finance: 
# Apple (AAPL) - https://finance.yahoo.com/quote/AAPL/history?period1=1518584400&period2=1550120400&interval=1d&filter=history&frequency=1d
# Facebook (FB) - https://finance.yahoo.com/quote/FB/history?period1=1518584400&period2=1550120400&interval=1d&filter=history&frequency=1d

fb1<-read.delim("AAPL.csv", header=TRUE, sep=",")
aapl1<-read.delim("FB.csv", header=TRUE, sep=",")
par(bg="cornsilk")
plot(aapl1$Adj.Close, col="blue", type="o",xlim=c(0,250), ylim=c(100,250), xlab="Days", ylab="Price" )
lines(fb1$Adj.Close, type="o", pch=22, lty=2, col="red")
legend("topright", inset=.05, c("Apple","Facebook"), fill=c("red","blue"), horiz=TRUE)
#Just study the distribution of the adjusted close of the stock price of Apple.
hist(aapl1$Adj.Close, col=rainbow(8))
# Out:
# plot without title
# Plot with title “Histogram of aapl1$Adj.Close”

# %% [markdown]
# The first graph plot depicts the comparison between approximately 250 readings of the Adjusted Closing Prices of Apple and Facebook in the span of 1 year. <br><br>
# We first plot the adjusted closing price of Apple using plot() and then we add the graph of adjusted closing price of Facebook using lines() <br><br>
# Analysis : In first 120 readings approximately, the adjusted closing prices for Apple and Facebook were comparable. Readings from thereafter had a great difference with prices of Apple high. The Histogram depicts the adjusted closing price of Apple for readings taken in a span of 1 year.<br><br>

# %% [markdown]
# ## Problem 5: Data sets available with R:  R community has created a lot of data for others to use. Examine the data sets already available with R. data(), attach(),detach(), head(), summary()

# %%
data() # To observe the data sets available for explorations.
attach(Orange) # Attach Dataset Orange To Search Path
head(Orange) # Return The First Or Last Part Of An Object
summary(Orange) # Summary of the dataset (or object)
detach(Orange) # To remove the data from the memory after analysis

# Also explore newer data sets in 
library (help=datasets) # Documentation for datasets
library(datasets)
head(eurodist)
plot(eurodist)
# Out:
#   Tree age  circumference
# 1 1     118  30
# 2 1     484  58
# 3 1     664  87
# 4 1    1004 115
# 5 1    1231 120
# 6 1    1372 142
#  Tree       age         circumference
#  3:7   Min.   : 118.0   Min.   : 30.0
#  1:7   1st Qu.: 484.0   1st Qu.: 65.5
#  5:7   Median :1004.0   Median :115.0
#  2:7   Mean   : 922.1   Mean   :115.9
#  4:7   3rd Qu.:1372.0   3rd Qu.:161.5
#        Max.   :1582.0   Max.   :214.0
# [1] 3313 2963 3175 3339 2762 3276
# plot without title

# %% [markdown]
# ## Problem 6: Accessing external APIs: eg. Google map lat-long API: “map” command. Get API key from Google Cloud.
# The idea here is to plot the results of analysis on a map: geographical or otherwise. List a collection of cities you have visited and plot it on a map.

# %%
library("ggmap")
library("maptools")
library(maps)
register_google(key = "AIzaSyDSEkc6UGy1_2s8cAkvf_kg_tvNXdI8f94") 
visited <- c("SFO", "Chennai", "London", "Melbourne", "Lima","Peru", "Johannesbury"," SA","Mumbai","Amsterdam")
ll.visited <- geocode(visited)
visit.x <- ll.visited$lon
visit.y <- ll.visited$lat
map("world", fill=TRUE, col="white", bg="lightblue", ylim=c(-60, 90), mar=c(0,0,0,0))
points(visit.x,visit.y, col="red", pch=20)
# Out:
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=SFO&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Chennai&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=London&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Melbourne&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Lima&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Peru&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Johannesbury&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=SA&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Mumbai&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Amsterdam&key=xxx
# plot without title

# %% [markdown]
# ## Problem 7

# %%
attach(mtcars)
head(mtcars)
plot(mtcars[c(1,3,4,5,6)], main="MTCARS Data")
plot(mtcars[c(1,3,4,6)], main="MTCARS Data")
plot(mtcars[c(1,3,4,6)], col=rainbow(5),main="MTCARS Data")
# Out:
# The following object is masked from package:ggplot2:
#
#     mpg
#                   mpg  cyl disp hp  drat wt    qsec  vs am gear carb
# Mazda RX4         21.0 6   160  110 3.90 2.620 16.46 0  1  4    4
# Mazda RX4 Wag     21.0 6   160  110 3.90 2.875 17.02 0  1  4    4
# Datsun 710        22.8 4   108   93 3.85 2.320 18.61 1  1  4    1
# Hornet 4 Drive    21.4 6   258  110 3.08 3.215 19.44 1  0  3    1
# Hornet Sportabout 18.7 8   360  175 3.15 3.440 17.02 0  0  3    2
# Valiant           18.1 6   225  105 2.76 3.460 20.22 1  0  3    1
# plot without title
# plot without title
# plot without title

# %% [markdown]
# ## Problem 8

# %%
library(ggplot2)
ggplot(mtcars, aes(x=mpg, y=disp)) + geom_point()
# Out:
# plot without title
